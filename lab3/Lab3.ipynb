# %%
import numpy as np
import os
import pandas as pd
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models, layers
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, MaxPool2D, Activation, Flatten, Dense, Dropout
import torchvision.models as models
from sklearn.manifold import TSNE
from keras.layers import concatenate, Dense, Input

# %%
LABELS = ['T-shirt/top','Trouser','Pullover','Dress',  'Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
from sklearn.model_selection import train_test_split
(x_train, y_train), (x_test, y_test) = datasets.fashion_mnist.load_data()
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# X_train shape: (60000, 28, 28)
# X_test shape: (10000, 28, 28)

# %%
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.

print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
# Out:
# X_train shape: (60000, 28, 28, 1)
# X_test shape: (10000, 28, 28, 1)

# %%
# reorganize by groups
train_groups = [x_train[np.where(y_train==i)[0]] for i in np.unique(y_train)]
test_groups = [x_test[np.where(y_test==i)[0]] for i in np.unique(y_train)]
print('train groups:', [x.shape[0] for x in train_groups])
print('test groups:', [x.shape[0] for x in test_groups])
# Out:
# train groups: [6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000]
# test groups: [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %%
def gen_random_batch(in_groups, batch_halfsize=8):
    out_img_a, out_img_b, out_score = [], [], []
    all_groups = list(range(len(in_groups)))
    for match_group in [True, False]:
        group_idx = np.random.choice(all_groups, size=batch_halfsize)
        out_img_a += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in group_idx]
        if match_group:
            b_group_idx = group_idx
            out_score += [1]*batch_halfsize
        else:
            # anything but the same group
            non_group_idx = [np.random.choice([i for i in all_groups if i != c_idx]) for c_idx in group_idx]
            b_group_idx = non_group_idx
            out_score += [0]*batch_halfsize
        out_img_b += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in b_group_idx]
    return np.stack(out_img_a,0), np.stack(out_img_b,0), np.stack(out_score,0)

# %%
pv_a, pv_b, pv_sim = gen_random_batch(train_groups, 3)
fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize=(12, 6))
for c_a, c_b, c_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, m_axs.T):
    ax1.imshow(c_a[:,:,0], cmap='gray')
    ax1.set_title('Image A')
    ax1.axis('off')
    ax2.imshow(c_b[:,:,0], cmap='gray')
    ax2.set_title('Image B\n Similarity: %3.0f%%' % (100*c_d))
    ax2.axis('off')

# %%
def conv2D_bn_relu(x, filters, kernel_size, strides, padding='valid', kernel_initializer='glorot_uniform', name=None):

    x = layers.Conv2D(filters=filters, 
                      kernel_size=kernel_size, 
                      strides=strides, 
                      padding=padding, 
                      kernel_initializer=kernel_initializer,
                      name=name,
                      use_bias=False)(x)
    x = layers.BatchNormalization(scale=False)(x)
    return layers.Activation('relu')(x)

# %%
def inception_module_A(x, filters=None, kernel_initializer='glorot_uniform'):
    pool = layers.AveragePooling2D(pool_size=(2, 2), strides=1, padding='same')(x)
    pool = conv2D_bn_relu(pool, 
                          filters=filters // (8/12), 
                          kernel_size=1, 
                          strides=1,
                          padding="same",
                          kernel_initializer=kernel_initializer)
    
    branch_1 = conv2D_bn_relu(x,
                              filters=filters // (8/12),
                              kernel_size=1,
                              strides=1,
                              padding="valid",
                              kernel_initializer=kernel_initializer)
    
    branch_2 = conv2D_bn_relu(x,
                              filters=filters,
                              kernel_size=1,
                              strides=1,
                              padding="valid",
                              kernel_initializer=kernel_initializer)
    branch_2 = conv2D_bn_relu(branch_2,
                              filters=filters // (8/12),
                              kernel_size=3,
                              strides=1,
                              padding="same",
                              kernel_initializer=kernel_initializer)
    
    branch_3 = conv2D_bn_relu(x,
                              filters=filters,
                              kernel_size=1,
                              strides=1,
                              padding="valid",
                              kernel_initializer=kernel_initializer)
    branch_3 = conv2D_bn_relu(branch_3,
                              filters=filters // (8/12),
                              kernel_size=3,
                              strides=1,
                              padding="same",
                              kernel_initializer=kernel_initializer)
    branch_3 = conv2D_bn_relu(branch_3,
                              filters=filters // (8/12),
                              kernel_size=3,
                              strides=1,
                              padding="same",
                              kernel_initializer=kernel_initializer)
    

    return layers.concatenate([branch_1, branch_2, branch_3, pool])

# %%
def inception_module_B(x, filters=None, kernel_initializer='glorot_uniform'):
    pool = layers.AveragePooling2D(pool_size=(2, 2),
                                   strides=1, 
                                   padding='same')(x)
    pool = conv2D_bn_relu(pool,
                          filters=filters//2,
                          kernel_size=1,
                          strides=1,
                          padding="same")

    branch_1 = conv2D_bn_relu(x,
                          filters=filters//(8/12),
                          kernel_size=1,
                          strides=1,
                          padding="valid")

    branch_2 = conv2D_bn_relu(x,
                          filters=filters//(8/6),
                          kernel_size=1,
                          strides=1,
                          padding="valid")
    branch_2 = conv2D_bn_relu(branch_2,
                              filters=filters,
                              kernel_size=(1,5),
                              strides=1,
                              padding="same")
    branch_2 = conv2D_bn_relu(branch_2,
                              filters=filters,
                              kernel_size=(5,1),
                              strides=1,
                              padding="same")

    branch_3 = conv2D_bn_relu(x,
                              filters=filters//(8/6),
                              kernel_size=1,
                              strides=1,
                              padding="valid")
    branch_3 = conv2D_bn_relu(x,
                              filters=filters//(8/6),
                              kernel_size=(1,5),
                              strides=1,
                              padding="same")
    branch_3 = conv2D_bn_relu(x,
                              filters=filters//(8/7),
                              kernel_size=(5,1),
                              strides=1,
                              padding="same")
    branch_3 = conv2D_bn_relu(x,
                              filters=filters//(8/7),
                              kernel_size=(1,5),
                              strides=1,
                              padding="same")
    branch_3 = conv2D_bn_relu(x,
                              filters=filters,
                              kernel_size=(5,1),
                              strides=1,
                              padding="same")


    x = layers.concatenate([pool, branch_1, branch_2, branch_3])
    return x

# %%
def inception_module_C(x, filters=None, kernel_initializer='glorot_uniform'):  
    pool = layers.AveragePooling2D(pool_size=(2, 2),
                                   strides=1, 
                                   padding='same')(x)
    pool = conv2D_bn_relu(pool,
                          filters=filters,
                          kernel_size=1,
                          strides=1,
                          padding="same")

    branch_1 = conv2D_bn_relu(x,
                          filters=filters,
                          kernel_size=1,
                          strides=1,
                          padding="valid")

    
    branch_2 = conv2D_bn_relu(x,
                          filters=filters//(8/12),
                          kernel_size=1,
                          strides=1,
                          padding="valid")
    
    branch_2_1 = conv2D_bn_relu(branch_2,
                          filters=filters,
                          kernel_size=(1,3),
                          strides=1,
                          padding="same")

    branch_2_2 = conv2D_bn_relu(branch_2,
                          filters=filters,
                          kernel_size=(3,1),
                          strides=1,
                          padding="same")

    branch_3 = conv2D_bn_relu(x,
                          filters=filters//(8/12),
                          kernel_size=(1,1),
                          strides=1,
                          padding="valid")
    branch_3 = conv2D_bn_relu(x,
                          filters=filters//(8/14),
                          kernel_size=(1,3),
                          strides=1,
                          padding="same")
    branch_3 = conv2D_bn_relu(x,
                          filters=filters//(4/8),
                          kernel_size=(3,1),
                          strides=1,
                          padding="same")
    
    branch_3_1 = conv2D_bn_relu(branch_3,
                          filters=filters,
                          kernel_size=(1,3),
                          strides=1,
                          padding="same")

    branch_3_2 = conv2D_bn_relu(branch_3,
                          filters=filters,
                          kernel_size=(3,1),
                          strides=1,
                          padding="same")

    return layers.concatenate([pool, branch_1, branch_2_1, branch_2_2,branch_3_1, branch_3_2])

# %%
inputs = layers.Input(shape=x_train.shape[1:])

x = conv2D_bn_relu(inputs,
                   filters=32,
                   kernel_size=(3,3),
                   strides=1,
                   padding="same")
x = conv2D_bn_relu(x,
                      filters=48,
                      kernel_size=(3,3),
                      strides=1,
                      padding="same")
x = conv2D_bn_relu(x,
                      filters=64,
                      kernel_size=(4,4),
                      strides=2,
                      padding="valid")

x = layers.SpatialDropout2D(rate=0.1)(x)
for i in range(4):
  x = inception_module_A(x, filters=32)
  x = layers.SpatialDropout2D(rate=0.2)(x)
for i in range(7):
  x = inception_module_B(x, filters=48)
  x = layers.SpatialDropout2D(rate=0.1)(x)
for i in range(3):
  x = inception_module_C(x, filters=64)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(30)(x)


model = keras.Model(inputs=inputs, outputs=x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 32)   288         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 28, 28, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 48)   13824       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 48)  144         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 28, 28, 48)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 13, 13, 64)   49152       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 13, 13, 64)  192         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 13, 13, 64)   0           ['batch_normalization_2[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 13, 13, 64)  0           ['activation_2[0][0]']
#  out2D)
#
#  conv2d_7 (Conv2D)              (None, 13, 13, 32)   2048        ['spatial_dropout2d[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 13, 13, 32)  96          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 13, 13, 32)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 13, 13, 32)   2048        ['spatial_dropout2d[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 13, 13, 48)   13824       ['activation_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 13, 13, 32)  96          ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 13, 13, 48)  144         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 13, 13, 32)   0           ['batch_normalization_5[0][0]']
#
#  activation_8 (Activation)      (None, 13, 13, 48)   0           ['batch_normalization_8[0][0]']
#
#  average_pooling2d (AveragePool  (None, 13, 13, 64)  0           ['spatial_dropout2d[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)              (None, 13, 13, 48)   3072        ['spatial_dropout2d[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 13, 13, 48)   13824       ['activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 13, 13, 48)   20736       ['activation_8[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 13, 13, 48)   3072        ['average_pooling2d[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 13, 13, 48)  144         ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 13, 13, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 13, 13, 48)  144         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 13, 13, 48)  144         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 13, 13, 48)   0           ['batch_normalization_4[0][0]']
#
#  activation_6 (Activation)      (None, 13, 13, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 13, 13, 48)   0           ['batch_normalization_9[0][0]']
#
#  activation_3 (Activation)      (None, 13, 13, 48)   0           ['batch_normalization_3[0][0]']
#
#  concatenate (Concatenate)      (None, 13, 13, 192)  0           ['activation_4[0][0]',
#                                                                   'activation_6[0][0]',
#                                                                   'activation_9[0][0]',
#                                                                   'activation_3[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate[0][0]']
#  opout2D)
#
#  conv2d_14 (Conv2D)             (None, 13, 13, 32)   6144        ['spatial_dropout2d_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 13, 13, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 13, 13, 32)   6144        ['spatial_dropout2d_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 13, 13, 48)   13824       ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 13, 13, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 13, 13, 48)  144         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_15 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_15[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_1[0][0]']
#  oling2D)
#
#  conv2d_11 (Conv2D)             (None, 13, 13, 48)   9216        ['spatial_dropout2d_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 13, 13, 48)   13824       ['activation_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 13, 13, 48)   20736       ['activation_15[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 13, 13, 48)   9216        ['average_pooling2d_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 13, 13, 48)  144         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 13, 13, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 13, 13, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 13, 13, 48)  144         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_11[0][0]']
#
#  activation_13 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_16[0][0]']
#
#  activation_10 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_10[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 13, 13, 192)  0           ['activation_11[0][0]',
#                                                                   'activation_13[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_10[0][0]']
#
#  spatial_dropout2d_2 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_1[0][0]']
#  opout2D)
#
#  conv2d_21 (Conv2D)             (None, 13, 13, 32)   6144        ['spatial_dropout2d_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 13, 13, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 13, 13, 32)   6144        ['spatial_dropout2d_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 13, 13, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 13, 13, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 13, 13, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_22[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_2[0][0]']
#  oling2D)
#
#  conv2d_18 (Conv2D)             (None, 13, 13, 48)   9216        ['spatial_dropout2d_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 13, 13, 48)   13824       ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 13, 13, 48)   20736       ['activation_22[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 13, 13, 48)   9216        ['average_pooling2d_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 13, 13, 48)  144         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 13, 13, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 13, 13, 48)  144         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 13, 13, 48)  144         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_23[0][0]']
#
#  activation_17 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_17[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 13, 13, 192)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]',
#                                                                   'activation_17[0][0]']
#
#  spatial_dropout2d_3 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_2[0][0]']
#  opout2D)
#
#  conv2d_28 (Conv2D)             (None, 13, 13, 32)   6144        ['spatial_dropout2d_3[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 13, 13, 32)  96          ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 13, 13, 32)   6144        ['spatial_dropout2d_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 13, 13, 48)   13824       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 13, 13, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 13, 13, 48)  144         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_29[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_3[0][0]']
#  oling2D)
#
#  conv2d_25 (Conv2D)             (None, 13, 13, 48)   9216        ['spatial_dropout2d_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 13, 13, 48)   13824       ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 13, 13, 48)   20736       ['activation_29[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 13, 13, 48)   9216        ['average_pooling2d_3[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 13, 13, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 13, 13, 48)  144         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 13, 13, 48)  144         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 13, 13, 48)  144         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_25[0][0]']
#
#  activation_27 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_27[0][0]']
#
#  activation_30 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_30[0][0]']
#
#  activation_24 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_24[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 13, 13, 192)  0           ['activation_25[0][0]',
#                                                                   'activation_27[0][0]',
#                                                                   'activation_30[0][0]',
#                                                                   'activation_24[0][0]']
#
#  spatial_dropout2d_4 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_3[0][0]']
#  opout2D)
#
#  conv2d_33 (Conv2D)             (None, 13, 13, 36)   6912        ['spatial_dropout2d_4[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 13, 13, 36)  108         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 13, 13, 36)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 13, 13, 48)   8640        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 13, 13, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  average_pooling2d_4 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_4[0][0]']
#  oling2D)
#
#  activation_34 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 13, 13, 24)   4608        ['average_pooling2d_4[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 13, 13, 72)   13824       ['spatial_dropout2d_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 13, 13, 48)   11520       ['activation_34[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 13, 13, 48)   46080       ['spatial_dropout2d_4[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 13, 13, 24)  72          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 13, 13, 72)  216         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 13, 13, 48)  144         ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 13, 13, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 13, 13, 24)   0           ['batch_normalization_31[0][0]']
#
#  activation_32 (Activation)     (None, 13, 13, 72)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_35[0][0]']
#
#  activation_40 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_40[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 13, 13, 192)  0           ['activation_31[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]',
#                                                                   'activation_40[0][0]']
#
#  spatial_dropout2d_5 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_4[0][0]']
#  opout2D)
#
#  conv2d_43 (Conv2D)             (None, 13, 13, 36)   6912        ['spatial_dropout2d_5[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 13, 13, 36)  108         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 13, 13, 36)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 13, 13, 48)   8640        ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 13, 13, 48)  144         ['conv2d_44[0][0]']
#  ormalization)
#
#  average_pooling2d_5 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_5[0][0]']
#  oling2D)
#
#  activation_44 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 13, 13, 24)   4608        ['average_pooling2d_5[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 13, 13, 72)   13824       ['spatial_dropout2d_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 13, 13, 48)   11520       ['activation_44[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 13, 13, 48)   46080       ['spatial_dropout2d_5[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 13, 13, 24)  72          ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 13, 13, 72)  216         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 13, 13, 48)  144         ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 13, 13, 48)  144         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 13, 13, 24)   0           ['batch_normalization_41[0][0]']
#
#  activation_42 (Activation)     (None, 13, 13, 72)   0           ['batch_normalization_42[0][0]']
#
#  activation_45 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_45[0][0]']
#
#  activation_50 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_50[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 13, 13, 192)  0           ['activation_41[0][0]',
#                                                                   'activation_42[0][0]',
#                                                                   'activation_45[0][0]',
#                                                                   'activation_50[0][0]']
#
#  spatial_dropout2d_6 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_5[0][0]']
#  opout2D)
#
#  conv2d_53 (Conv2D)             (None, 13, 13, 36)   6912        ['spatial_dropout2d_6[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 13, 13, 36)  108         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 13, 13, 36)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 13, 13, 48)   8640        ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 13, 13, 48)  144         ['conv2d_54[0][0]']
#  ormalization)
#
#  average_pooling2d_6 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_6[0][0]']
#  oling2D)
#
#  activation_54 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 13, 13, 24)   4608        ['average_pooling2d_6[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 13, 13, 72)   13824       ['spatial_dropout2d_6[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 13, 13, 48)   11520       ['activation_54[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 13, 13, 48)   46080       ['spatial_dropout2d_6[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 13, 13, 24)  72          ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 13, 13, 72)  216         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 13, 13, 48)  144         ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 13, 13, 48)  144         ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 13, 13, 24)   0           ['batch_normalization_51[0][0]']
#
#  activation_52 (Activation)     (None, 13, 13, 72)   0           ['batch_normalization_52[0][0]']
#
#  activation_55 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_55[0][0]']
#
#  activation_60 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_60[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 13, 13, 192)  0           ['activation_51[0][0]',
#                                                                   'activation_52[0][0]',
#                                                                   'activation_55[0][0]',
#                                                                   'activation_60[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_6[0][0]']
#  opout2D)
#
#  conv2d_63 (Conv2D)             (None, 13, 13, 36)   6912        ['spatial_dropout2d_7[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 13, 13, 36)  108         ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 13, 13, 36)   0           ['batch_normalization_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 13, 13, 48)   8640        ['activation_63[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 13, 13, 48)  144         ['conv2d_64[0][0]']
#  ormalization)
#
#  average_pooling2d_7 (AveragePo  (None, 13, 13, 192)  0          ['spatial_dropout2d_7[0][0]']
#  oling2D)
#
#  activation_64 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_64[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 13, 13, 24)   4608        ['average_pooling2d_7[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 13, 13, 72)   13824       ['spatial_dropout2d_7[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 13, 13, 48)   11520       ['activation_64[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 13, 13, 48)   46080       ['spatial_dropout2d_7[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 13, 13, 24)  72          ['conv2d_61[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 13, 13, 72)  216         ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 13, 13, 48)  144         ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 13, 13, 48)  144         ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 13, 13, 24)   0           ['batch_normalization_61[0][0]']
#
#  activation_62 (Activation)     (None, 13, 13, 72)   0           ['batch_normalization_62[0][0]']
#
#  activation_65 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_65[0][0]']
#
#  activation_70 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_70[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 13, 13, 192)  0           ['activation_61[0][0]',
#                                                                   'activation_62[0][0]',
#                                                                   'activation_65[0][0]',
#                                                                   'activation_70[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 13, 13, 192)  0          ['concatenate_7[0][0]']
#  opout2D)
#
#  conv2d_73 (Conv2D)             (None, 13, 13, 36)   6912        ['spatial_dropout2d_8[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 13, 13, 36)  108         ['conv2d_73[0][0]']
# ...
#
#  activation_102 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_102[0][0]']
#
#  activation_104 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_105[0][0]']
#
#  activation_109 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_109[0][0]']
#
#  activation_110 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_110[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 13, 13, 384)  0           ['activation_101[0][0]',
#                                                                   'activation_102[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]',
#                                                                   'activation_109[0][0]',
#                                                                   'activation_110[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 13, 13, 96)   36864       ['concatenate_11[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 13, 13, 128)  147456      ['concatenate_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 13, 13, 96)  288         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 13, 13, 128)  384        ['conv2d_118[0][0]']
#  Normalization)
#
#  average_pooling2d_12 (AverageP  (None, 13, 13, 384)  0          ['concatenate_11[0][0]']
#  ooling2D)
#
#  activation_113 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_113[0][0]']
#
#  activation_118 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_118[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 13, 13, 64)   24576       ['average_pooling2d_12[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 13, 13, 64)   24576       ['concatenate_11[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 13, 13, 64)   18432       ['activation_113[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 13, 13, 64)   18432       ['activation_113[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 13, 13, 64)   24576       ['activation_118[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 13, 13, 64)   24576       ['activation_118[0][0]']
#
#  batch_normalization_111 (Batch  (None, 13, 13, 64)  192         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 13, 13, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 13, 13, 64)  192         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 13, 13, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 13, 13, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_120 (Batch  (None, 13, 13, 64)  192         ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_112[0][0]']
#
#  activation_114 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_114[0][0]']
#
#  activation_115 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_119 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_119[0][0]']
#
#  activation_120 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_120[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 13, 13, 384)  0           ['activation_111[0][0]',
#                                                                   'activation_112[0][0]',
#                                                                   'activation_114[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_119[0][0]',
#                                                                   'activation_120[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 13, 13, 96)   36864       ['concatenate_12[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 13, 13, 128)  147456      ['concatenate_12[0][0]']
#
#  batch_normalization_123 (Batch  (None, 13, 13, 96)  288         ['conv2d_123[0][0]']
#  Normalization)
#
#  batch_normalization_128 (Batch  (None, 13, 13, 128)  384        ['conv2d_128[0][0]']
#  Normalization)
#
#  average_pooling2d_13 (AverageP  (None, 13, 13, 384)  0          ['concatenate_12[0][0]']
#  ooling2D)
#
#  activation_123 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_123[0][0]']
#
#  activation_128 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 13, 13, 64)   24576       ['average_pooling2d_13[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 13, 13, 64)   24576       ['concatenate_12[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 13, 13, 64)   18432       ['activation_123[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 13, 13, 64)   18432       ['activation_123[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 13, 13, 64)   24576       ['activation_128[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 13, 13, 64)   24576       ['activation_128[0][0]']
#
#  batch_normalization_121 (Batch  (None, 13, 13, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 13, 13, 64)  192         ['conv2d_122[0][0]']
#  Normalization)
#
#  batch_normalization_124 (Batch  (None, 13, 13, 64)  192         ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_125 (Batch  (None, 13, 13, 64)  192         ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_129 (Batch  (None, 13, 13, 64)  192         ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 13, 13, 64)  192         ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_121[0][0]']
#
#  activation_122 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_122[0][0]']
#
#  activation_124 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_124[0][0]']
#
#  activation_125 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_125[0][0]']
#
#  activation_129 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_129[0][0]']
#
#  activation_130 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_130[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 13, 13, 384)  0           ['activation_121[0][0]',
#                                                                   'activation_122[0][0]',
#                                                                   'activation_124[0][0]',
#                                                                   'activation_125[0][0]',
#                                                                   'activation_129[0][0]',
#                                                                   'activation_130[0][0]']
#
#  global_average_pooling2d (Glob  (None, 384)         0           ['concatenate_13[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 384)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 30)           11550       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,868,914
# Trainable params: 1,858,682
# Non-trainable params: 10,232
# __________________________________________________________________________________________________

# %%
img_a_in = Input(shape = x_train.shape[1:], name = 'ImageA_Input')
img_b_in = Input(shape = x_train.shape[1:], name = 'ImageB_Input')

img_a_feat = model(img_a_in)
img_b_feat = model(img_b_in)

combined_features = concatenate([img_a_feat, img_b_feat], name =
'merge_features')
combined_features = Dense(15, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(4, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(1, activation = 'sigmoid')(combined_features)
similarity_model = keras.Model(inputs = [img_a_in, img_b_in], outputs =
[combined_features], name = 'Similarity_Model')
similarity_model.summary()
# Out:
# Model: "Similarity_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ImageA_Input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  ImageB_Input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  model (Functional)             (None, 30)           1868914     ['ImageA_Input[0][0]',
#                                                                   'ImageB_Input[0][0]']
#
#  merge_features (Concatenate)   (None, 60)           0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  dense_1 (Dense)                (None, 15)           915         ['merge_features[0][0]']
#
#  batch_normalization_131 (Batch  (None, 15)          60          ['dense_1[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 15)           0           ['batch_normalization_131[0][0]']
#
#  dense_2 (Dense)                (None, 4)            64          ['activation_131[0][0]']
#
#  batch_normalization_132 (Batch  (None, 4)           16          ['dense_2[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 4)            0           ['batch_normalization_132[0][0]']
#
#  dense_3 (Dense)                (None, 1)            5           ['activation_132[0][0]']
#
# ==================================================================================================
# Total params: 1,869,974
# Trainable params: 1,859,704
# Non-trainable params: 10,270
# __________________________________________________________________________________________________

# %%
similarity_model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['mae'])

# %%
def show_model_output(nb_examples = 3):
  pv_a, pv_b, pv_sim = gen_random_batch(test_groups, nb_examples)
  pred_sim = similarity_model.predict([pv_a, pv_b])
  fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
  for c_a, c_b, c_d, p_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, pred_sim, m_axs.T):
    ax1.imshow(c_a[:,:,0], cmap='gray')
    ax1.set_title('Image A\n Actual: %3.0f%%' % (100*c_d))
    ax1.axis('off')
    ax2.imshow(c_b[:,:,0], cmap='gray')
    ax2.set_title('Image B\n Predicted: %3.0f%%' % (100*p_d))
    ax2.axis('off')
  return fig
  #completely untrained model
_ = show_model_output()

# %%
# make a generator out of the data
def siam_gen(in_groups, batch_size = 32):
  while True:
    pv_a, pv_b, pv_sim = gen_random_batch(train_groups, batch_size//2)
    yield [pv_a, pv_b], pv_sim

valid_a, valid_b, valid_sim = gen_random_batch(test_groups, 1024)
loss_history = similarity_model.fit(siam_gen(train_groups), steps_per_epoch = 250, validation_data=([valid_a, valid_b], valid_sim), epochs = 20, verbose = True)
# Out:
# Epoch 1/20
# 250/250 [==============================] - 103s 327ms/step - loss: 0.6934 - mae: 0.4951 - val_loss: 0.7085 - val_mae: 0.4980
# Epoch 2/20
# 250/250 [==============================] - 76s 304ms/step - loss: 0.5841 - mae: 0.4204 - val_loss: 0.5389 - val_mae: 0.3419
# Epoch 3/20
# 250/250 [==============================] - 75s 300ms/step - loss: 0.5101 - mae: 0.3654 - val_loss: 0.5030 - val_mae: 0.2802
# Epoch 4/20
# 250/250 [==============================] - 75s 301ms/step - loss: 0.4737 - mae: 0.3325 - val_loss: 0.4919 - val_mae: 0.2885
# Epoch 5/20
# 250/250 [==============================] - 75s 301ms/step - loss: 0.4442 - mae: 0.3081 - val_loss: 0.4055 - val_mae: 0.2726
# Epoch 6/20
# 250/250 [==============================] - 75s 302ms/step - loss: 0.4256 - mae: 0.2910 - val_loss: 0.4157 - val_mae: 0.2706
# Epoch 7/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.4208 - mae: 0.2825 - val_loss: 0.4048 - val_mae: 0.2769
# Epoch 8/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.4060 - mae: 0.2707 - val_loss: 0.3752 - val_mae: 0.2489
# Epoch 9/20
# 250/250 [==============================] - 75s 301ms/step - loss: 0.4079 - mae: 0.2706 - val_loss: 0.3740 - val_mae: 0.2454
# Epoch 10/20
# 250/250 [==============================] - 75s 302ms/step - loss: 0.4019 - mae: 0.2621 - val_loss: 0.3770 - val_mae: 0.2468
# Epoch 11/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.3925 - mae: 0.2579 - val_loss: 0.3660 - val_mae: 0.2331
# Epoch 12/20
# 250/250 [==============================] - 75s 300ms/step - loss: 0.3834 - mae: 0.2520 - val_loss: 0.3474 - val_mae: 0.2311
# Epoch 13/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.4136 - mae: 0.2636 - val_loss: 0.4184 - val_mae: 0.2543
# Epoch 14/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.3912 - mae: 0.2557 - val_loss: 0.3474 - val_mae: 0.2317
# Epoch 15/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.3820 - mae: 0.2485 - val_loss: 0.3537 - val_mae: 0.2267
# Epoch 16/20
# 250/250 [==============================] - 75s 300ms/step - loss: 0.3692 - mae: 0.2393 - val_loss: 0.3350 - val_mae: 0.2207
# Epoch 17/20
# 250/250 [==============================] - 75s 301ms/step - loss: 0.3614 - mae: 0.2349 - val_loss: 0.3582 - val_mae: 0.2256
# Epoch 18/20
# 250/250 [==============================] - 75s 298ms/step - loss: 0.3453 - mae: 0.2228 - val_loss: 0.3269 - val_mae: 0.2102
# Epoch 19/20
# 250/250 [==============================] - 75s 299ms/step - loss: 0.3597 - mae: 0.2267 - val_loss: 0.3243 - val_mae: 0.2062
# Epoch 20/20
# 250/250 [==============================] - 75s 301ms/step - loss: 0.3519 - mae: 0.2261 - val_loss: 0.3151 - val_mae: 0.2041

# %%
_ = show_model_output()

# %%
x_test_features = model.predict(x_test, verbose = True, batch_size=128)
# Out:
# 79/79 [==============================] - 14s 116ms/step

# %%
tsne_obj = TSNE(n_components=2,init='pca',random_state=101, method='barnes_hut',n_iter=500,verbose=2)
tsne_features = tsne_obj.fit_transform(x_test_features)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.001s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 10000 samples in 4.046s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.160837
# [t-SNE] Computed conditional probabilities in 0.584s
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# [t-SNE] Iteration 50: error = 58.4080315, gradient norm = 0.0035573 (50 iterations in 5.489s)
# [t-SNE] Iteration 100: error = 59.1854897, gradient norm = 0.0015588 (50 iterations in 4.993s)
# [t-SNE] Iteration 150: error = 59.3847198, gradient norm = 0.0013700 (50 iterations in 4.862s)
# [t-SNE] Iteration 200: error = 59.5460205, gradient norm = 0.0024670 (50 iterations in 4.910s)
# [t-SNE] Iteration 250: error = 59.8528099, gradient norm = 0.0009759 (50 iterations in 4.909s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.852810
# [t-SNE] Iteration 300: error = 1.6013900, gradient norm = 0.0010240 (50 iterations in 5.247s)
# [t-SNE] Iteration 350: error = 1.3163475, gradient norm = 0.0004618 (50 iterations in 5.413s)
# [t-SNE] Iteration 400: error = 1.1827952, gradient norm = 0.0002857 (50 iterations in 5.377s)
# [t-SNE] Iteration 450: error = 1.0995429, gradient norm = 0.0002085 (50 iterations in 5.382s)
# [t-SNE] Iteration 500: error = 1.0382943, gradient norm = 0.0001647 (50 iterations in 5.437s)
# [t-SNE] KL divergence after 500 iterations: 1.038294

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, 10)) 
plt.figure(figsize=(10, 10))
for c_group, (c_color, c_label) in enumerate(zip(colors, LABELS)):
    plt.scatter(tsne_features[np.where(y_test == c_group), 0],  tsne_features[np.where(y_test == c_group), 1],  marker='o', color=c_color, linewidth=1, alpha=0.8, label=c_label) 
plt.xlabel('Dimension 1') 
plt.ylabel('Dimension 2') 
plt.title('t-SNE on Testing Samples') 
plt.legend(loc='best')  
plt.show(block=False)

# %%
def plot_history(history):
    plt.title('Train/validation loss')
    plt.plot(history.history['loss'], label = 'training loss')
    plt.plot(history.history['val_loss'], label = 'validation loss')
    plt.grid()
    plt.legend()
    plt.ylim(0,1)
    plt.show()

plot_history(loss_history)
